# %% [markdown]
# <a href="https://colab.research.google.com/github/DeveloperAkram/Colab-Notebooks/blob/master/ML7012_Gradient_Descent_Algorithm_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Dependencies

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,5])

# %%
# %matplotlib inline

def gradient_descent(x, y):
  m_curr = b_curr = 0
  iterations = 50
  L = 0.001
  n = len(x)
  plt.scatter(x, y, color = 'red', marker='+', linewidths='5')
  for i in range(iterations):
    y_pred = m_curr * x + b_curr
    cost = (1/n)*sum([val **2 for val in (y-y_pred)])
    plt.plot(x,y_pred, color = 'green')
    md = -(2/n)*sum(x*(y-y_pred))
    bd = -(2/n)*sum(y-y_pred)
    m_curr = m_curr - L*md
    b_curr = b_curr - L*bd
    print("m{}, b{}, cost{}, iterations{} ".format(m_curr, b_curr, cost, i))

# %%
gradient_descent(x, y)
# Out:
# m0.026400000000000003, b0.008, cost17.2, iterations0
# m0.0521712, b0.015825600000000002, cost16.448037760000002, iterations1
# m0.07732848, b0.023480921600000003, cost15.731219988075521, iterations2
# m0.10188636791040001, b0.030969988876800005, cost15.047903204747364, iterations3
# m0.12585904788311042, b0.038296730691584006, cost14.396520786073076, iterations4
# m0.14926036844553248, b0.045464982942902174, cost13.775579369580624, iterations5
# m0.17210385044207335, b0.05247849076634318, cost13.183655428274745, iterations6
# m0.19440269478774969, b0.059340910682158056, cost12.619392004856152, iterations7
# m0.21616979003832626, b0.06605581269206724, cost12.081495598661483, iterations8
# m0.2374177197813307, b0.07262668232645315, cost11.568733198182144, iterations9
# m0.2581587698521827, b0.07905692264311226, cost11.0799294523542, iterations10
# m0.278404935379576, b0.08534985617871294, cost10.613963974129863, iterations11
# ...
